# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load CSV file
df = pd.read_csv("info.csv")

# View first rows
df.head()
# Out:
#        File No        Team 1  Team 1 Runs  ...  Winner Runs Winner Wickets  Method
# 0   710305.csv    Bangladesh          326  ...          NaN            3.0     NaN
# 1   667889.csv       England          247  ...         81.0            NaN     D/L
# 2  1073420.csv      Pakistan           91  ...          NaN            6.0     NaN
# 3   749547.csv        Jersey          185  ...          NaN            7.0     NaN
# 4   463154.csv  South Africa          250  ...         33.0            NaN     D/L
#
# [5 rows x 29 columns]

# %%
# Dataset info
df.info()

# Statistical summary
df.describe()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File No          1669 non-null   str
#  1   Team 1           1669 non-null   str
#  2   Team 1 Runs      1669 non-null   int64
#  3   Team 1 Wickets   1669 non-null   int64
#  4   Team 2           1669 non-null   str
#  5   Team 2 Runs      1669 non-null   int64
#  6   Team 2 Wickets   1669 non-null   int64
#  7   Gender           1669 non-null   str
#  8   Season           1669 non-null   str
#  9   Date             1669 non-null   str
#  10  Series           1030 non-null   str
#  11  Competition      664 non-null    str
#  12  Match Number     1477 non-null   float64
#  13  Venue            1669 non-null   str
#  14  City             1414 non-null   str
#  15  Neutral Venue    466 non-null    object
#  16  Toss Winner      1669 non-null   str
#  17  Toss Decision    1669 non-null   str
#  18  Player of Match  1562 non-null   str
#  19  Umpire 1         1669 non-null   str
#  20  Umpire 2         1669 non-null   str
#  21  Reserve Umpire   1527 non-null   str
#  22  TV Umpire        1292 non-null   str
#  23  Match Referee    1635 non-null   str
#  24  Winner           1630 non-null   str
#  25  Outcome          39 non-null     str
#  26  Winner Runs      808 non-null    float64
#  27  Winner Wickets   822 non-null    float64
#  28  Method           156 non-null    str
# dtypes: float64(3), int64(4), object(1), str(21)
# memory usage: 677.4+ KB
# File No               0
# Team 1                0
# Team 1 Runs           0
# Team 1 Wickets        0
# Team 2                0
# Team 2 Runs           0
# Team 2 Wickets        0
# Gender                0
# Season                0
# Date                  0
# Series              639
# Competition        1005
# Match Number        192
# Venue                 0
# City                255
# Neutral Venue      1203
# Toss Winner           0
# Toss Decision         0
# Player of Match     107
# Umpire 1              0
# Umpire 2              0
# Reserve Umpire      142
# TV Umpire           377
# Match Referee        34
# Winner               39
# Outcome            1630
# Winner Runs         861
# Winner Wickets      847
# Method             1513
# dtype: int64

# %%
# Convert categorical columns into numbers
df = pd.get_dummies(df, drop_first=True)
